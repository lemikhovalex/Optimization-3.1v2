# %%
import numpy as np
from numpy import linalg
import math
from matplotlib import pylab as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
def surface_plot (matrix, **kwargs):
    # acquire the cartesian coordinate matrices from the matrix
    # x is cols, y is rows
    (x, y) = np.meshgrid(np.arange(matrix.shape[1]), np.arange(matrix.shape[0]))
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(x, y, matrix, **kwargs)
    return (fig, ax, surf)

# %%
n_to_read = 6
d_to_read = 9

# %%
def read_dataset(file_name):
    global n_to_read
    global d_to_read
    out = np.zeros((n_to_read, d_to_read))
    f = open(file_name, 'r')
    for i in range(n_to_read):
        s = f.readline()
        tokens = s.split(' ')
        line_to_write = []
        for j in range(d_to_read):
            tok_tok = []
            tok_tok = str(tokens[j]).split('_')
            print(tok_tok)
            line_to_write.append(tok_tok[1])
            out[i][j] = line_to_write[j]
    print out
    return out

# %%
u = read_dataset("plots8.txt")

(fig, ax, surf) = surface_plot(u, cmap=plt.cm.coolwarm)

fig.colorbar(surf)

ax.set_xlabel('p')
ax.set_ylabel('slaves (cores)')
ax.set_zlabel('u (values)')

plt.show()
# Out:
# ['0.040530587506172465', '12.075781869888306']
# ['0.008787356117753166', '6.689775371551514']
# ['0.034020564068146214', '6.086104488372802']
# ['0.0076607833301907576', '5.520101737976074']
# ['0.01029007227032282', '4.691483974456787']
# ['0.025567098692792948', '4.7432310581207275']
# ['0.017249093019551055', '4.540447187423706']
# ['0.026355373694984887', '4.283322858810425']
# ['0.024707172082007123', '4.3648138523101805']
# ['0.06814160413377927', '15.398874473571777']
# ['0.061036143862040364', '8.315884971618653']
# ['0.14017539462662068', '6.251265668869019']
# ['0.09505221973617714', '5.437153577804565']
# ['0.8420448689629296', '7.72229642868042']
# ['0.18361136964434377', '12.763975381851196']
# ['0.6963630464299084', '14.500858163833618']
# ['0.41503184531667664', '14.501590061187745']
# ['0.05604362891496109', '17.49811840057373']
# ['0.03475426154117948', '12.697055530548095']
# ['0.09358073290701754', '7.196406412124634']
# ['0.0874026663277556', '5.5048106670379635']
# ['0.030956774093936573', '4.674846601486206']
# ['0.10123216643362082', '4.190464830398559']
# ['0.04190425448825975', '3.8419955730438233']
# ['0.4525713456841936', '4.299180936813355']
# ['0.3792065077693144', '4.419976997375488']
# ['0.10423833227849842', '3.988579750061035']
# ['0.009655217384657097', '9.03542857170105']
# ['0.03304049669629195', '5.373848009109497']
# ['0.013135432987142722', '4.291719675064087']
# ['0.031186202629055054', '3.7252336025238035']
# ['0.04147321618462386', '3.4684712409973146']
# ['0.04809504655157295', '3.241374158859253']
# ['0.06748857941966194', '3.0020530223846436']
# ['0.027284039487063632', '2.8823055267333983']
# ['0.055253371832770244', '2.9129520416259767']
# ['0.02545289155138401', '9.798667860031127']
# ['0.052596647827002144', '5.7274376392364506']
# ['0.02515624342877695', '4.4286988258361815']
# ['0.03772400949267992', '3.827102613449097']
# ['0.03332832825940323', '3.4383214473724366']
# ['0.019564751658745813', '3.192387914657593']
# ['0.037380080022877765', '2.9995327472686766']
# ['0.03134358303992054', '2.8749963283538817']
# ['0.044757475067778024', '2.8202844142913817']
# ['0.0663991751085323', '10.494896125793456']
# ['0.04922715234177431', '6.02138843536377']
# ['0.03566809214324618', '4.651984453201294']
# ['0.044792050411062954', '3.955321025848389']
# ['0.7241703154641217', '4.969137239456177']
# ['0.051446113887307666', '3.4620251178741457']
# ['0.07665763264096129', '3.103760862350464']
# ['0.05163226591994314', '2.8820738315582277']
# ['0.05258787831356649', '2.797235631942749']
# [[12.07578187  6.68977537  6.08610449  5.52010174  4.69148397  4.74323106
#    4.54044719  4.28332286  4.36481385]
#  [15.39887447  8.31588497  6.25126567  5.43715358  7.72229643 12.76397538
#   14.50085816 14.50159006 17.4981184 ]
#  [12.69705553  7.19640641  5.50481067  4.6748466   4.19046483  3.84199557
#    4.29918094  4.419977    3.98857975]
#  [ 9.03542857  5.37384801  4.29171968  3.7252336   3.46847124  3.24137416
#    3.00205302  2.88230553  2.91295204]
#  [ 9.79866786  5.72743764  4.42869883  3.82710261  3.43832145  3.19238791
#    2.99953275  2.87499633  2.82028441]
#  [10.49489613  6.02138844  4.65198445  3.95532103  4.96913724  3.46202512
#    3.10376086  2.88207383  2.79723563]]
# <img src="data:image/png;base64,..." width="639.4">
